# %%
import pygmt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import bordado as bd
import boule as bl
import harmonica as hm
import verde as vd

import spherical as sph

# %% [markdown]
# Import and print the real data.

# %%
arquivo = '/home/arthur/Documentos/ANP_MAG/teste.csv'
saida = '/home/arthur/Documentos/ANP_MAG/0001_PARANA_1Hz.csv'

linhas_validas = []
indice_cabecalho = None

header = False
last_line = 0
with open(arquivo, 'r') as f:
    count = 0
    for linha in f:
        if not linha.strip().startswith('/'):
            if not header:
                cabecalho = linha.strip().split(',')
                header = True
                continue
            if linha.strip().split(',')[2] != last_line:
                last_line = linha.strip().split(',')[2]
            with open(f'tmp/{last_line}.csv', "a") as out:

                out.write(linha)                    
                count += 1

# %%
with open('tmp/10530.csv', 'r') as f:
    count = 1
    first_line = True

    for linha in f:
        valores = linha.strip().split(',')

        if first_line:
            # constantes
            fid = valores[0]
            estacao = valores[1]
            linha_voo = valores[2]
            data = valores[7]
            hora = valores[8]
            
            # inicializar arrays com o primeiro valor
            x = np.array([float(valores[3])])
            y = np.array([float(valores[4])])
            lat = np.array([float(valores[5])])
            lon = np.array([float(valores[6])])
            gpsalt = np.array([float(valores[9])])
            baro = np.array([float(valores[10])])
            magbru = np.array([float(valores[11])])
            magcom = np.array([float(valores[12])])
            magbase = np.array([float(valores[13])])
            magcor = np.array([float(valores[14])])
            maginv = np.array([float(valores[15])])
            magmic = np.array([float(valores[16])])
            magigrf = np.array([float(valores[17])])
            igrf = np.array([float(valores[18])])
            mdt = np.array([float(valores[19])])

            count += 1
            first_line = False
            continue

        if count <= 99:
            x = np.append(x, float(valores[3]))
            y = np.append(y, float(valores[4]))
            lat = np.append(lat, float(valores[5]))
            lon = np.append(lon, float(valores[6]))
            gpsalt = np.append(gpsalt, float(valores[9]))
            baro = np.append(baro, float(valores[10]))
            magbru = np.append(magbru, float(valores[11]))
            magcom = np.append(magcom, float(valores[12]))
            magbase = np.append(magbase, float(valores[13]))
            magcor = np.append(magcor, float(valores[14]))
            maginv = np.append(maginv, float(valores[15]))
            magmic = np.append(magmic, float(valores[16]))
            magigrf = np.append(magigrf, float(valores[17]))
            igrf = np.append(igrf, float(valores[18]))
            mdt = np.append(mdt, float(valores[19]))

            count += 1
            continue

        # calcular médias com 4 casas decimais
        x_mean = f"{x.mean():.4f}"
        y_mean = f"{y.mean():.4f}"
        lat_mean = f"{lat.mean():.4f}"
        lon_mean = f"{lon.mean():.4f}"
        gpsalt_mean = f"{gpsalt.mean():.4f}"
        baro_mean = f"{baro.mean():.4f}"
        magbru_mean = f"{magbru.mean():.4f}"
        magcom_mean = f"{magcom.mean():.4f}"
        magbase_mean = f"{magbase.mean():.4f}"
        magcor_mean = f"{magcor.mean():.4f}"
        maginv_mean = f"{maginv.mean():.4f}"
        magmic_mean = f"{magmic.mean():.4f}"
        magigrf_mean = f"{magigrf.mean():.4f}"
        igrf_mean = f"{igrf.mean():.4f}"
        mdt_mean = f"{mdt.mean():.4f}"

        x = [] 
        y = []
        lat = []
        lon = []
        gpsalt = []
        baro = []
        magbru = []
        magcom = []
        magbase = []
        magcor = []
        maginv = []
        magmic = []
        magigrf = []
        igrf = []
        mdt = []
        print(count)

        # escrever na ordem correta
        with open(f'tmp/{linha_voo}_mean.csv', "a") as out:
            out.write(
                f"{fid},{estacao},{linha_voo},"
                f"{x_mean},{y_mean},{lat_mean},{lon_mean},"
                f"{data},{hora},{gpsalt_mean},{baro_mean},"
                f"{magbru_mean},{magcom_mean},{magbase_mean},{magcor_mean},"
                f"{maginv_mean},{magmic_mean},{magigrf_mean},{igrf_mean},{mdt_mean}\n"
            )
            count = 1
            first_line = True
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# ...
